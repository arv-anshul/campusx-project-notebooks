# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

from easy_analysis.data import summary
from easy_analysis.plots import univariate

# %%
pd.set_option("display.max_columns", None)

# %%
df = pd.read_csv("data/processed/gurgaon_10k.csv")
print(df.shape)
df.head()
# Out:
# (10162, 33)
#        SPID    PROP_ID     CITY        PRICE  PRICE_SQFT    AREA  \
# 0  70597758  h70597758  gurgaon   31900000.0     20202.0  1579.0
# 1  70436188  h70436188  gurgaon   18500000.0      9135.0  2025.0
# 2  70217014  l70217014  gurgaon  120600000.0     42736.0  2822.0
# 3  70217012  x70217012  gurgaon   95300000.0     42736.0  2229.0
# 4  70217010  a70217010  gurgaon   72000000.0     43834.0  1642.0
#
#    TOTAL_LANDMARK_COUNT                      PROP_HEADING  \
# 0                   9.0  3 bhk flat in sector 113 gurgaon
# 1                  12.0   3 bhk flat in sector 77 gurgaon
# 2                   9.0   5 bhk flat in sector 53 gurgaon
# 3                   9.0   4 bhk flat in sector 53 gurgaon
# 4                   9.0   3 bhk flat in sector 53 gurgaon
#
#                                          DESCRIPTION          PROPERTY_TYPE  \
# 0  there is a 3 bhk apartment in sector 113, gurg...  residential apartment
# 1  let your dream of owning a flat come true with...  residential apartment
# 2  tulip monsella offers 5 bhk flats in sector 53...  residential apartment
# 3  tulip monsella offers 4 bhk flats in sector 53...  residential apartment
# 4  tulip monsella offers 3 bhk apartments in sect...  residential apartment
#
#          FURNISH         FACING                    AGE TOTAL_FLOOR  \
# 0  not available  not available     Under Construction       15-30
# 1  not available  not available  0-1 Year Old Property       15-30
# 2  not available  not available     Under Construction       15-30
# 3  not available  not available     Under Construction       15-30
# 4  not available  not available     Under Construction       15-30
#
#    BEDROOM_NUM                PROP_NAME  BALCONY_NUM FLOOR_NUM   LATITUDE  \
# 0          3.0  la vida by tata housing          NaN       <15  28.532594
# 1          3.0       emaar palm heights          NaN       <15  28.385577
# 2          5.0           tulip monsella          NaN       <15  28.435057
# 3          4.0           tulip monsella          NaN       <15  28.435057
# 4          3.0           tulip monsella          NaN       <15  28.435057
#
#    LONGITUDE  BHK_BED        LOCALITY_NAME            BUILDING_NAME  \
# 0  77.020297      3.0  sector 113 gurgaon   la vida by tata housing
# 1  76.975992      3.0    sector 77 gurgaon       emaar palm heights
# 2  77.101367      5.0    sector 53 gurgaon           tulip monsella
# 3  77.101367      4.0    sector 53 gurgaon           tulip monsella
# 4  77.101367      3.0    sector 53 gurgaon           tulip monsella
#
#               SOCIETY_NAME ADDRESS  TRANSPORATION  ACCOMODATION  LEISURE  \
# 0  la vida by tata housing     NaN            3.0           0.0      1.0
# 1       emaar palm heights     NaN            3.0           1.0      4.0
# 2           tulip monsella     NaN            1.0           2.0      2.0
# 3           tulip monsella     NaN            1.0           2.0      2.0
# 4           tulip monsella     NaN            1.0           2.0      2.0
#
#    EDUCATION  HEALTH  OTHER  AMENITIES_SCORE  FEATURES_SCORE
# 0        2.0     1.0    2.0                0               0
# 1        2.0     1.0    1.0                0               0
# 2        2.0     1.0    1.0                0               0
# 3        2.0     1.0    1.0                0               0
# 4        2.0     1.0    1.0                0               0

# %%
df["PROPERTY_TYPE"].value_counts()
# Out:
# PROPERTY_TYPE
# residential apartment        5952
# independent/builder floor    2470
# residential land              989
# independent house/villa       621
# farm house                    120
# serviced apartments            10
# Name: count, dtype: int64

# %%
df.drop(
    index=df.query("PROPERTY_TYPE==['farm house', 'serviced apartments']").index,
    inplace=True,
)
df.shape
# Out:
# (10032, 33)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10032 entries, 0 to 10161
# Data columns (total 33 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   SPID                  10032 non-null  int64
#  1   PROP_ID               10032 non-null  object
#  2   CITY                  10032 non-null  object
#  3   PRICE                 10032 non-null  float64
#  4   PRICE_SQFT            10032 non-null  float64
#  5   AREA                  10032 non-null  float64
#  6   TOTAL_LANDMARK_COUNT  9971 non-null   float64
#  7   PROP_HEADING          10032 non-null  object
#  8   DESCRIPTION           10032 non-null  object
#  9   PROPERTY_TYPE         10032 non-null  object
#  10  FURNISH               10032 non-null  object
#  11  FACING                10032 non-null  object
#  12  AGE                   10032 non-null  object
#  13  TOTAL_FLOOR           10032 non-null  object
#  14  BEDROOM_NUM           9034 non-null   float64
#  15  PROP_NAME             8228 non-null   object
#  16  BALCONY_NUM           8885 non-null   float64
#  17  FLOOR_NUM             10032 non-null  object
#  18  LATITUDE              10032 non-null  float64
#  19  LONGITUDE             10032 non-null  float64
#  20  BHK_BED               9034 non-null   float64
#  21  LOCALITY_NAME         10032 non-null  object
#  22  BUILDING_NAME         8228 non-null   object
#  23  SOCIETY_NAME          8228 non-null   object
#  24  ADDRESS               4896 non-null   object
#  25  TRANSPORATION         10032 non-null  float64
#  26  ACCOMODATION          10032 non-null  float64
#  27  LEISURE               10032 non-null  float64
#  28  EDUCATION             10032 non-null  float64
#  29  HEALTH                10032 non-null  float64
#  30  OTHER                 10032 non-null  float64
#  31  AMENITIES_SCORE       10032 non-null  int64
#  32  FEATURES_SCORE        10032 non-null  int64
# dtypes: float64(15), int64(3), object(15)
# memory usage: 2.6+ MB

# %%
df.isnull().sum()
# Out:
# SPID                       0
# PROP_ID                    0
# CITY                       0
# PRICE                      0
# PRICE_SQFT                 0
# AREA                       0
# TOTAL_LANDMARK_COUNT      61
# PROP_HEADING               0
# DESCRIPTION                0
# PROPERTY_TYPE              0
# FURNISH                    0
# FACING                     0
# AGE                        0
# TOTAL_FLOOR                0
# BEDROOM_NUM              998
# PROP_NAME               1804
# BALCONY_NUM             1147
# FLOOR_NUM                  0
# LATITUDE                   0
# LONGITUDE                  0
# BHK_BED                  998
# LOCALITY_NAME              0
# BUILDING_NAME           1804
# SOCIETY_NAME            1804
# ADDRESS                 5136
# TRANSPORATION              0
# ACCOMODATION               0
# LEISURE                    0
# EDUCATION                  0
# HEALTH                     0
# OTHER                      0
# AMENITIES_SCORE            0
# FEATURES_SCORE             0
# dtype: int64

# %%
df.columns
# Out:
# Index(['SPID', 'PROP_ID', 'CITY', 'PRICE', 'PRICE_SQFT', 'AREA',
#        'TOTAL_LANDMARK_COUNT', 'PROP_HEADING', 'DESCRIPTION', 'PROPERTY_TYPE',
#        'FURNISH', 'FACING', 'AGE', 'TOTAL_FLOOR', 'BEDROOM_NUM', 'PROP_NAME',
#        'BALCONY_NUM', 'FLOOR_NUM', 'LATITUDE', 'LONGITUDE', 'BHK_BED',
#        'LOCALITY_NAME', 'BUILDING_NAME', 'SOCIETY_NAME', 'ADDRESS',
#        'TRANSPORATION', 'ACCOMODATION', 'LEISURE', 'EDUCATION', 'HEALTH',
#        'OTHER', 'AMENITIES_SCORE', 'FEATURES_SCORE'],
#       dtype='object')

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# ## CITY

# %%
df["CITY"].value_counts()
# Out:
# CITY
# gurgaon    10032
# Name: count, dtype: int64

# %% [markdown]
# ## PRICE

# %%
summary.custom_describe(df["PRICE"])
# Out:
#                  PRICE
# count     1.003200e+04
# mean      2.414677e+07
# std       3.615741e+07
# min       5.500000e+03
# 1%        1.800000e+04
# 5%        3.200000e+04
# 25%       1.700000e+05
# 50%       1.700000e+07
# 75%       3.210000e+07
# 95%       7.200000e+07
# 99%       1.450000e+08
# max       1.200000e+09
# skew      9.135352e+00
# kurtosis  1.948629e+02
# notnull   1.003200e+04
# isnull    0.000000e+00

# %%
univariate.univariate_eda(df["PRICE"], compare=True, ecdf=True, qqplot_kw={"dist": "log"})

# %% [markdown]
# ### Low Price DataFrame

# %%
# PRICE < 2 Lacs
low_price_df = df.query("PRICE<20_000")
print(low_price_df.shape)
low_price_df.sample(5)
# Out:
# (121, 33)
#           SPID    PROP_ID     CITY    PRICE  PRICE_SQFT    AREA  \
# 6604  70882446  o70882446  gurgaon  15100.0        24.0   605.0
# 7213  70910358  e70910358  gurgaon  16000.0        25.0   632.0
# 4613  70523906  v70523906  gurgaon  15000.0        28.0   626.0
# 1704  70402474  f70402474  gurgaon  12000.0        23.0   519.0
# 1541  70666054  s70666054  gurgaon  15000.0        14.0  1000.0
#
#       TOTAL_LANDMARK_COUNT                                       PROP_HEADING  \
# 6604                  10.0                   2 bhk flat in sector 102 gurgaon
# 7213                  10.0                   2 bhk flat in sector 102 gurgaon
# 4613                  15.0                    2 bhk flat in sector 90 gurgaon
# 1704                  10.0                   2 bhk flat in sector 37d gurgaon
# 1541                  46.0  3 bhk independent builder floor in ashok vihar...
#
#                                             DESCRIPTION  \
# 6604  situated in sector 102 gurgaon gurgaon, suncit...
# 7213  suncity avenue 102 is one of gurgaon's most so...
# 4613  a spacious 2 bhk flat for rent is available in...
# 1704  situated in sector 37d gurgaon gurgaon, signat...
# 1541  carefully laid out in the prime location of gu...
#
#                   PROPERTY_TYPE        FURNISH      FACING  \
# 6604      residential apartment  Semifurnished        East
# 7213      residential apartment  Semifurnished  North-East
# 4613      residential apartment  Semifurnished  North-East
# 1704      residential apartment    Unfurnished        East
# 1541  independent/builder floor  Semifurnished  North-East
#
#                         AGE TOTAL_FLOOR  BEDROOM_NUM  \
# 6604  1-5 Year Old Property         <15          2.0
# 7213  1-5 Year Old Property         <15          2.0
# 4613  0-1 Year Old Property         <15          2.0
# 1704  0-1 Year Old Property         <15          2.0
# 1541  1-5 Year Old Property         <15          3.0
#
#                            PROP_NAME  BALCONY_NUM FLOOR_NUM   LATITUDE  \
# 6604              suncity avenue 102          1.0       <15  28.472115
# 7213              suncity avenue 102          1.0       <15  28.474697
# 4613                     green court          1.0       <15  28.404822
# 1704  signature global the millennia          3.0       <15  28.446875
# 1541                             NaN          1.0       <15  28.459896
#
#       LONGITUDE  BHK_BED        LOCALITY_NAME                   BUILDING_NAME  \
# 6604  76.966707      2.0   sector 102 gurgaon              suncity avenue 102
# 7213  76.968627      2.0   sector 102 gurgaon              suncity avenue 102
# 4613  76.929875      2.0    sector 90 gurgaon                     green court
# 1704  76.983994      2.0   sector 37d gurgaon  signature global the millennia
# 1541  77.098816      3.0  ashok vihar phase 2                             NaN
#
#                         SOCIETY_NAME  \
# 6604              suncity avenue 102
# 7213              suncity avenue 102
# 4613                     green court
# 1704  signature global the millennia
# 1541                             NaN
#
#                                                 ADDRESS  TRANSPORATION  \
# 6604                                                NaN            2.0
# 7213                                                NaN            2.0
# 4613                                                502            0.0
# 1704                                                NaN            3.0
# 1541  2690/30,near shiv shakti mandir opposite new s...            3.0
#
#       ACCOMODATION  LEISURE  EDUCATION  HEALTH  OTHER  AMENITIES_SCORE  \
# 6604           0.0      2.0        3.0     2.0    1.0              101
# 7213           0.0      2.0        3.0     2.0    1.0               42
# 4613           2.0      2.0        4.0     3.0    4.0               48
# 1704           2.0      2.0        1.0     1.0    1.0               49
# 1541           5.0      0.0        2.0    10.0    3.0                0
#
#       FEATURES_SCORE
# 6604              47
# 7213              15
# 4613              15
# 1704              15
# 1541               0

# %%
low_price_df["PROPERTY_TYPE"].value_counts()
# Out:
# PROPERTY_TYPE
# residential apartment        96
# independent/builder floor    21
# independent house/villa       4
# Name: count, dtype: int64

# %%
low_price_df["LOCALITY_NAME"].value_counts()
# Out:
# LOCALITY_NAME
# sector 37d gurgaon             14
# sector 95 gurgaon              12
# sector 86 gurgaon              11
# sohna                           9
# sector 82 gurgaon               7
# sector 102 gurgaon              7
# sector 95a gurgaon              6
# sector 90 gurgaon               6
# sector 83 gurgaon               6
# sector 56 gurgaon               5
# sector 70a gurgaon              4
# sector 107 gurgaon              3
# sector 37c gurgaon              2
# sector 81 gurgaon               2
# sector 103 gurgaon              2
# sector 99 gurgaon               2
# sector 92 gurgaon               2
# sector 67 gurgaon               2
# sector 23a gurgaon              2
# sector 2 gurgaon                2
# dwarka expressway gurgaon       1
# sector 88a gurgaon              1
# sector 67a gurgaon              1
# malibu town                     1
# sector-33 sohna                 1
# ashok vihar phase 2             1
# sector 22 gurgaon               1
# c block sushant lok phase 1     1
# sector 23 gurgaon               1
# sector 84 gurgaon               1
# sector 26 gurgaon               1
# sector 104 gurgaon              1
# acharya puri extension          1
# sector 21 gurgaon               1
# sector 54 gurgaon               1
# Name: count, dtype: int64

# %%
summary.custom_describe(low_price_df["PRICE"])
# Out:
#                  PRICE
# count       121.000000
# mean      15063.619835
# std        3096.686746
# min        5500.000000
# 1%         7100.000000
# 5%         8500.000000
# 25%       13500.000000
# 50%       15000.000000
# 75%       17500.000000
# 95%       19000.000000
# 99%       19500.000000
# max       19500.000000
# skew         -0.846638
# kurtosis      0.350788
# notnull     121.000000
# isnull        0.000000

# %%
univariate.visualise_feature(low_price_df["PRICE"])

# %% [markdown]
# ### High Price DataFrame

# %%
# PRICE > 96%tile
high_price_df = df.query(f"PRICE>{df['PRICE'].quantile(0.96)}")
print(high_price_df.shape)
high_price_df.sample(5)
# Out:
# (396, 33)
#           SPID    PROP_ID     CITY        PRICE  PRICE_SQFT    AREA  \
# 8929  70047684  z70047684  gurgaon   82500000.0    110000.0  6750.0
# 9033  70364170  l70364170  gurgaon   97500000.0     25090.0  3886.0
# 33    70991572  o70991572  gurgaon   84500000.0    281666.0  2700.0
# 5218  70089736  e70089736  gurgaon  108000000.0    300000.0  3240.0
# 6536  68942562  k68942562  gurgaon  104900000.0     26225.0  4000.0
#
#       TOTAL_LANDMARK_COUNT                                    PROP_HEADING  \
# 8929                  10.0    residential land / plot in sector 99 gurgaon
# 9033                   9.0                 4 bhk flat in sector 54 gurgaon
# 33                     3.0                  5 bedroom house in dlf phase 2
# 5218                  47.0                 12 bedroom house in dlf phase 4
# 6536                   8.0  5 bhk independent builder floor in dlf phase 5
#
#                                             DESCRIPTION  \
# 8929  g99 in sector-99 gurgaon, gurgaon by the uppal...
# 9033  it's excellent location gives you the boon of ...
# 33    north east facing well renovated villa best bl...
# 5218  360 yards beautiful house for sale in dlf phas...
# 6536  dlf grove is independent floor developing by d...
#
#                   PROPERTY_TYPE        FURNISH         FACING  \
# 8929           residential land  not available     North-East
# 9033      residential apartment  Semifurnished  not available
# 33      independent house/villa  Semifurnished     North-East
# 5218    independent house/villa  Semifurnished          North
# 6536  independent/builder floor  Semifurnished           East
#
#                         AGE TOTAL_FLOOR  BEDROOM_NUM               PROP_NAME  \
# 8929              Undefined         <15          NaN                     g99
# 9033  10+ Year Old Property       15-30          4.0  emaar the palm springs
# 33    1-5 Year Old Property         <15          5.0  dlf city plots phase 2
# 5218  1-5 Year Old Property         <15         12.0                     NaN
# 6536     Under Construction         <15          5.0           dlf the grove
#
#       BALCONY_NUM FLOOR_NUM   LATITUDE  LONGITUDE  BHK_BED      LOCALITY_NAME  \
# 8929          NaN       >30  28.463121  76.962544      NaN  sector 99 gurgaon
# 9033          4.0       <15  28.446850  77.102071      4.0  sector 54 gurgaon
# 33            4.0       >30  28.489563  77.087681      5.0        dlf phase 2
# 5218          4.0       >30  28.465786  77.083806     12.0        dlf phase 4
# 6536          3.0       <15  28.440290  77.109390      5.0        dlf phase 5
#
#                BUILDING_NAME            SOCIETY_NAME            ADDRESS  \
# 8929                     g99                     g99                NaN
# 9033  emaar the palm springs  emaar the palm springs                NaN
# 33    dlf city plots phase 2  dlf city plots phase 2  north east facing
# 5218                     NaN                     NaN                NaN
# 6536           dlf the grove           dlf the grove                204
#
#       TRANSPORATION  ACCOMODATION  LEISURE  EDUCATION  HEALTH  OTHER  \
# 8929            1.0           1.0      2.0        2.0     1.0    3.0
# 9033            2.0           0.0      2.0        3.0     0.0    2.0
# 33              0.0           0.0      1.0        1.0     1.0    0.0
# 5218            3.0           3.0      0.0        2.0    13.0    2.0
# 6536            2.0           0.0      1.0        2.0     1.0    2.0
#
#       AMENITIES_SCORE  FEATURES_SCORE
# 8929               24               0
# 9033               72              53
# 33                107              55
# 5218               51              12
# 6536              114              55

# %%
high_price_df["PROPERTY_TYPE"].value_counts()
# Out:
# PROPERTY_TYPE
# residential land             133
# independent house/villa      126
# residential apartment        119
# independent/builder floor     18
# Name: count, dtype: int64

# %%
high_price_df["LOCALITY_NAME"].value_counts()
# Out:
# LOCALITY_NAME
# dlf phase 1            37
# sector 54 gurgaon      35
# sector 42 gurgaon      30
# dlf phase 2            22
# sector 65 gurgaon      22
#                        ..
# v block dlf phase 3     1
# gwal pahari             1
# ansal palam vihar       1
# sector 106 gurgaon      1
# sector 83 gurgaon       1
# Name: count, Length: 72, dtype: int64

# %%
summary.custom_describe(high_price_df["PRICE"])
# Out:
#                  PRICE
# count     3.960000e+02
# mean      1.424747e+08
# std       1.016342e+08
# min       8.050000e+07
# 1%        8.128500e+07
# 5%        8.280000e+07
# 25%       9.500000e+07
# 50%       1.100000e+08
# 75%       1.450000e+08
# 95%       3.000000e+08
# 99%       5.000000e+08
# max       1.200000e+09
# skew      5.373789e+00
# kurtosis  4.316695e+01
# notnull   3.960000e+02
# isnull    0.000000e+00

# %%
univariate.visualise_feature(high_price_df["PRICE"])

# %% [markdown]
# #### For now, all the feature seems right to me except the `PRICE, PRICE_SQFT, AREA` are odd.
#
# - I can't ignore/drop them because they are **about 3000+ data**.
# - I need to go to the website using its the property URL and investigate what's happening.
#
# **This same senario goes for `PRICE_SQFT` and `AREA` features. That's why I am not going to analyse them like this.**
#
# - I am going to drop these for now to perform better EDA.

# %% [markdown]
# ## AREA

# %%
summary.custom_describe(df["AREA"])
# Out:
#                    AREA
# count      10032.000000
# mean        2829.715461
# std        14399.361193
# min           30.000000
# 1%           360.000000
# 5%           900.000000
# 25%         1593.000000
# 50%         2072.000000
# 75%         2700.000000
# 95%         4518.000000
# 99%         8747.100000
# max       737147.000000
# skew          38.558635
# kurtosis    1632.837747
# notnull    10032.000000
# isnull         0.000000

# %%
univariate.univariate_eda(df["AREA"], compare=True, ecdf=True, qqplot_kw={"dist": "log"})

# %% [markdown]
# ### High Area DataFrame

# %%
# PRICE > 95%tile
high_area_df = df.query(f"AREA>{df['AREA'].quantile(0.95)}")
high_area_df.shape
# Out:
# (446, 33)

# %%
summary.custom_describe(high_area_df["AREA"])
# Out:
#                    AREA
# count        446.000000
# mean       17712.141256
# std        66524.264090
# min         4520.000000
# 1%          4548.000000
# 5%          4600.000000
# 25%         4992.000000
# 50%         6000.000000
# 75%         7900.000000
# 95%        43560.000000
# 99%       407394.350000
# max       737147.000000
# skew           8.167064
# kurtosis      71.290734
# notnull      446.000000
# isnull         0.000000

# %%
univariate.compare_plot(high_area_df["AREA"])

# %%
univariate.qqplot(high_area_df["AREA"], "log")

# %% [markdown]
# ## filtered_df
#
# `filtered_df` repersents the perfect dataset for the model because it has no outliers for `PRICE` and `AREA` features.

# %%
filtered_df = df.copy(True)
filtered_df.shape
# Out:
# (10032, 33)

# %%
filtered_df.drop(index=low_price_df.index, inplace=True, errors="ignore")
filtered_df.drop(index=high_price_df.index, inplace=True, errors="ignore")
filtered_df.drop(index=high_area_df.index, inplace=True, errors="ignore")
filtered_df.shape
# Out:
# (9232, 33)

# %%
summary.custom_describe(df[["PRICE", "AREA"]])
# Out:
#                  PRICE           AREA
# count     1.003200e+04   10032.000000
# mean      2.414677e+07    2829.715461
# std       3.615741e+07   14399.361193
# min       5.500000e+03      30.000000
# 1%        1.800000e+04     360.000000
# 5%        3.200000e+04     900.000000
# 25%       1.700000e+05    1593.000000
# 50%       1.700000e+07    2072.000000
# 75%       3.210000e+07    2700.000000
# 95%       7.200000e+07    4518.000000
# 99%       1.450000e+08    8747.100000
# max       1.200000e+09  737147.000000
# skew      9.135352e+00      38.558635
# kurtosis  1.948629e+02    1632.837747
# notnull   1.003200e+04   10032.000000
# isnull    0.000000e+00       0.000000

# %% [markdown]
# ### PRICE

# %%
summary.compare_describe(df["PRICE"], filtered_df["PRICE"], reciprocal_ratio=True)
# Out:
#           PRICE as data1  PRICE as data2  data1 - data2  data1 ÷ data2  \
# count       1.003200e+04    9.232000e+03   8.000000e+02       1.086655
# mean        2.414677e+07    1.913926e+07   5.007507e+06       1.261635
# std         3.615741e+07    1.785140e+07   1.830601e+07       2.025466
# min         5.500000e+03    2.000000e+04  -1.450000e+04       0.275000
# 1%          1.800000e+04    2.350000e+04  -5.500000e+03       0.765957
# 5%          3.200000e+04    3.400000e+04  -2.000000e+03       0.941176
# 25%         1.700000e+05    1.500000e+05   2.000000e+04       1.133333
# 50%         1.700000e+07    1.650000e+07   5.000000e+05       1.030303
# 75%         3.210000e+07    2.850000e+07   3.600000e+06       1.126316
# 95%         7.200000e+07    5.500000e+07   1.700000e+07       1.309091
# 99%         1.450000e+08    7.106900e+07   7.393100e+07       2.040271
# max         1.200000e+09    8.000000e+07   1.120000e+09      15.000000
# skew        9.135352e+00    9.521263e-01   8.183226e+00       9.594685
# kurtosis    1.948629e+02    4.768828e-01   1.943860e+02     408.617893
# notnull     1.003200e+04    9.232000e+03   8.000000e+02       1.086655
# isnull      0.000000e+00    0.000000e+00   0.000000e+00            NaN
#
#           data2 ÷ data1
# count          0.920255
# mean           0.792622
# std            0.493714
# min            3.636364
# 1%             1.305556
# 5%             1.062500
# 25%            0.882353
# 50%            0.970588
# 75%            0.887850
# 95%            0.763889
# 99%            0.490131
# max            0.066667
# skew           0.104224
# kurtosis       0.002447
# notnull        0.920255
# isnull              NaN

# %%
univariate.univariate_eda(filtered_df["PRICE"], compare=True, ecdf=True)

# %% [markdown]
# ### AREA

# %%
summary.compare_describe(df["AREA"], filtered_df["AREA"], reciprocal_ratio=True)
# Out:
#           AREA as data1  AREA as data2  data1 - data2  data1 ÷ data2  \
# count      10032.000000    9232.000000     800.000000       1.086655
# mean        2829.715461    2119.352632     710.362828       1.335179
# std        14399.361193     822.352124   13577.009069      17.509970
# min           30.000000      30.000000       0.000000       1.000000
# 1%           360.000000     357.240000       2.760000       1.007726
# 5%           900.000000     900.000000       0.000000       1.000000
# 25%         1593.000000    1572.000000      21.000000       1.013359
# 50%         2072.000000    2000.000000      72.000000       1.036000
# 75%         2700.000000    2592.000000     108.000000       1.041667
# 95%         4518.000000    3670.900000     847.100000       1.230761
# 99%         8747.100000    4500.000000    4247.100000       1.943800
# max       737147.000000    4518.000000  732629.000000     163.157813
# skew          38.558635       0.577257      37.981378      66.796286
# kurtosis    1632.837747       0.565645    1632.272101    2886.680423
# notnull    10032.000000    9232.000000     800.000000       1.086655
# isnull         0.000000       0.000000       0.000000            NaN
#
#           data2 ÷ data1
# count          0.920255
# mean           0.748963
# std            0.057110
# min            1.000000
# 1%             0.992333
# 5%             1.000000
# 25%            0.986817
# 50%            0.965251
# 75%            0.960000
# 95%            0.812506
# 99%            0.514456
# max            0.006129
# skew           0.014971
# kurtosis       0.000346
# notnull        0.920255
# isnull              NaN

# %%
univariate.univariate_eda(filtered_df["AREA"], compare=True, ecdf=True)

# %% [markdown]
# ---
#
# ---

# %% [markdown]
# ## TOTAL_LANDMARK_COUNT

# %%
summary.custom_describe(df["TOTAL_LANDMARK_COUNT"])
# Out:
#           TOTAL_LANDMARK_COUNT
# count              9971.000000
# mean                 21.860696
# std                  16.447910
# min                   1.000000
# 1%                    3.000000
# 5%                    6.000000
# 25%                  10.000000
# 50%                  13.000000
# 75%                  45.000000
# 95%                  48.000000
# 99%                  50.000000
# max                  50.000000
# skew                  0.741010
# kurtosis             -1.286856
# notnull            9971.000000
# isnull               61.000000

# %%
sns.histplot(df["TOTAL_LANDMARK_COUNT"], kde=True)
# Out:
# <Axes: xlabel='TOTAL_LANDMARK_COUNT', ylabel='Count'>

# %%
sns.boxplot(df["TOTAL_LANDMARK_COUNT"])
# Out:
# <Axes: >

# %% [markdown]
# ## PROPERTY_HEADING

# %%
df["PROP_HEADING"].sample(10)
# Out:
# 2748     4 bhk independent builder floor in sector 65 g...
# 1771                       3 bhk flat in sector 83 gurgaon
# 7558                      3 bhk flat in sector 102 gurgaon
# 8745                      2 bhk flat in sector 106 gurgaon
# 10061                      3 bhk flat in sector 56 gurgaon
# 7027                        2 bhk flat in sector 3 gurgaon
# 9136                     4 bhk flat in sushant lok phase 1
# 6496        3 bhk independent builder floor in malibu town
# 7088                       3 bhk flat in sector 77 gurgaon
# 3270                       3 bhk flat in sector 59 gurgaon
# Name: PROP_HEADING, dtype: object

# %% [markdown]
# `PROP_HEADING` is just contains **bhk, property type and locality name** of the correspoing property.

# %% [markdown]
# ## DESCRIPTION

# %%
df["DESCRIPTION"].sample(10)
# Out:
# 9085    joyville 1368sqft 2 bhk - ready to move in  ne...
# 5053    this property is located in sector 70, it has ...
# 4320    check out this 3 bhk apartment for sale in par...
# 9915    gated society 3 bedroom with power backup, lif...
# 2135    sushant lok 1 . most prime location of gurugra...
# 54      this project ranks amongst the most popular pr...
# 4249    new luxury builder floor for sale  greenwood c...
# 2226    this 2 bhk flat is located in indiabulls centr...
# 4744    uppal southend s block sector 49 gurgaon  3bhk...
# 1780    5 bhk luxury builder floor available in malibu...
# Name: DESCRIPTION, dtype: object

# %% [markdown]
# ## PROPERTY_TYPE

# %%
df["PROPERTY_TYPE"].value_counts()
# Out:
# PROPERTY_TYPE
# residential apartment        5952
# independent/builder floor    2470
# residential land              989
# independent house/villa       621
# Name: count, dtype: int64

# %% [markdown]
# ### Extract all different `PROPERTY_TYPE`

# %%
res_apartment = df.query("PROPERTY_TYPE=='residential apartment'")
ind_builder_floor = df.query("PROPERTY_TYPE=='independent/builder floor'")
res_land = df.query("PROPERTY_TYPE=='residential land'")
ind_house = df.query("PROPERTY_TYPE=='independent house/villa'")

# %% [markdown]
# #### PRICE

# %%
plot_type = "Univariate Plots of"

univariate.univariate_eda(
    res_apartment["PRICE"],
    f"{plot_type} Residendial Apartment",
    compare=True,
)
univariate.univariate_eda(
    ind_builder_floor["PRICE"],
    f"{plot_type} Independent Builder Floor",
    compare=True,
)
univariate.univariate_eda(
    res_land["PRICE"],
    f"{plot_type} Residendial Land",
    compare=True,
)
univariate.univariate_eda(
    ind_house["PRICE"],
    f"{plot_type} Independent House",
    compare=True,
)
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#                              Univariate Plots of Residendial Apartment
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#                            Univariate Plots of Independent Builder Floor
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#                                 Univariate Plots of Residendial Land
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#                                Univariate Plots of Independent House
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# ## FURNISH

# %%
df["FURNISH"].value_counts().plot.bar()
# Out:
# <Axes: xlabel='FURNISH'>

# %% [markdown]
# - Highly imblacnced.
# - Many properties have not a `FURNISH` value i.e. **not available**.

# %% [markdown]
# ## FACING

# %%
df["FACING"].value_counts().plot.bar()
# Out:
# <Axes: xlabel='FACING'>

# %% [markdown]
# - Imblacnced.
# - Many values are missing i.e. **not available**.

# %% [markdown]
# ## AGE

# %%
df["AGE"].value_counts().plot.bar()
# Out:
# <Axes: xlabel='AGE'>

# %%
df.query("AGE=='Undefined'").sample(7)
# Out:
#           SPID    PROP_ID     CITY        PRICE  PRICE_SQFT    AREA  \
# 8501  68260032  e68260032  gurgaon   39100000.0    157480.0  2286.0
# 6458  70739386  w70739386  gurgaon  115100000.0    115100.0  9000.0
# 1185  70206674  q70206674  gurgaon   45000000.0    150000.0  2700.0
# 5418  70542334  s70542334  gurgaon   39000000.0    191176.0  1836.0
# 4626  70251286  w70251286  gurgaon    3440000.0      3675.0   936.0
# 9438  70860790  u70860790  gurgaon   11300000.0     75000.0   150.0
# 960   69882872  b69882872  gurgaon   18000000.0    120000.0  1350.0
#
#       TOTAL_LANDMARK_COUNT                                   PROP_HEADING  \
# 8501                  10.0   residential land / plot in sector 99 gurgaon
# 6458                  12.0   residential land / plot in sector 67 gurgaon
# 1185                  10.0   residential land / plot in sector 84 gurgaon
# 5418                  45.0   residential land / plot in sector 57 gurgaon
# 4626                  18.0  residential land / plot in sector 67a gurgaon
# 9438                   5.0   residential land / plot in sector 95 gurgaon
# 960                   10.0  residential land / plot in sector 82a gurgaon
#
#                                             DESCRIPTION     PROPERTY_TYPE  \
# 8501  its a 3 side 254 sq yd plot for immediate sale...  residential land
# 6458  its 1000 sq yards plot is available on sale in...  residential land
# 1185  this plot is 300 sq yd main road facing sale f...  residential land
# 5418  8 matlab plot for sale in sector 57. south eas...  residential land
# 4626  near mumbai expressway sohna city plot sohna i...  residential land
# 9438  brought to you by solutrean building technolog...  residential land
# 960   vatika india next 2 is an integrated township ...  residential land
#
#             FURNISH      FACING        AGE TOTAL_FLOOR  BEDROOM_NUM  \
# 8501  not available       North  Undefined         <15          NaN
# 6458  not available        East  Undefined         <15          NaN
# 1185  not available        East  Undefined         <15          NaN
# 5418  not available  South-East  Undefined         <15          NaN
# 4626  not available  North-East  Undefined         <15          NaN
# 9438  not available  North-West  Undefined         <15          NaN
# 960   not available        East  Undefined         <15          NaN
#
#                   PROP_NAME  BALCONY_NUM FLOOR_NUM   LATITUDE  LONGITUDE  \
# 8501                    g99          NaN       >30  28.463121  76.962544
# 6458      ansal api esencia          NaN       >30  28.432024  76.985959
# 1185                    NaN          NaN       >30  28.408166  76.962866
# 5418                    NaN          NaN       >30  28.423441  77.076593
# 4626                    NaN          NaN       >30  28.382146  77.055471
# 9438                    NaN          NaN       >30  28.414324  76.908124
# 960   vatika one india next          NaN       >30  28.385906  76.968939
#
#       BHK_BED       LOCALITY_NAME          BUILDING_NAME  \
# 8501      NaN   sector 99 gurgaon                    g99
# 6458      NaN   sector 67 gurgaon      ansal api esencia
# 1185      NaN   sector 84 gurgaon                    NaN
# 5418      NaN   sector 57 gurgaon                    NaN
# 4626      NaN  sector 67a gurgaon                    NaN
# 9438      NaN   sector 95 gurgaon                    NaN
# 960       NaN  sector 82a gurgaon  vatika one india next
#
#                SOCIETY_NAME  ADDRESS  TRANSPORATION  ACCOMODATION  LEISURE  \
# 8501                    g99      NaN            1.0           1.0      2.0
# 6458      ansal api esencia      NaN            1.0           0.0      0.0
# 1185                    NaN  block n            0.0           0.0      1.0
# 5418                    NaN      NaN            0.0           4.0      4.0
# 4626                    NaN      NaN            0.0           2.0      0.0
# 9438                    NaN     it57            0.0           0.0      0.0
# 960   vatika one india next      NaN            0.0           0.0      1.0
#
#       EDUCATION  HEALTH  OTHER  AMENITIES_SCORE  FEATURES_SCORE
# 8501        2.0     1.0    3.0               18               0
# 6458        5.0     4.0    2.0               24               0
# 1185        0.0     1.0    5.0               24               0
# 5418        0.0    15.0    5.0               19               0
# 4626        0.0     7.0    1.0               17               0
# 9438        0.0     4.0    1.0               24               0
# 960         0.0     1.0    3.0               24               0

# %% [markdown]
# ## TOTAL_FLOOR

# %%
df["TOTAL_FLOOR"].value_counts().plot.bar()
# Out:
# <Axes: xlabel='TOTAL_FLOOR'>

# %%
summary.custom_describe(df.query("TOTAL_FLOOR=='>30'")[["PRICE", "AREA"]])
# Out:
#                  PRICE           AREA
# count     1.187000e+03    1187.000000
# mean      3.180344e+07    3379.129318
# std       4.240808e+07   10917.494868
# min       2.800000e+04     232.000000
# 1%        4.500000e+04    1000.000000
# 5%        5.965000e+04    1300.000000
# 25%       2.250000e+05    1799.500000
# 50%       2.400000e+07    2468.000000
# 75%       4.450000e+07    2979.000000
# 95%       8.250000e+07    5092.000000
# 99%       1.457000e+08   11505.000000
# max       5.000000e+08  258879.000000
# skew      5.607333e+00      17.279780
# kurtosis  5.023382e+01     336.560489
# notnull   1.187000e+03    1187.000000
# isnull    0.000000e+00       0.000000

# %% [markdown]
# ## BEDROOM_NUM

# %%
df["BEDROOM_NUM"].value_counts().sort_index().plot.bar()
# Out:
# <Axes: xlabel='BEDROOM_NUM'>

# %%
gt_5bhk = df.query("BEDROOM_NUM>5")
print(gt_5bhk.shape)
summary.custom_describe(gt_5bhk[["PRICE", "AREA"]])
# Out:
# (164, 33)
#                  PRICE          AREA
# count     1.640000e+02    164.000000
# mean      6.428183e+07   4042.823171
# std       5.896572e+07   4872.287166
# min       1.250000e+05    122.000000
# 1%        1.657500e+05    225.710000
# 5%        2.957500e+05    551.850000
# 25%       2.995000e+07   1935.000000
# 50%       5.225000e+07   2700.000000
# 75%       8.492500e+07   4500.000000
# 95%       1.695500e+08   9500.000000
# 99%       3.055500e+08  18385.000000
# max       4.300000e+08  50580.000000
# skew      2.547788e+00      6.162342
# kurtosis  1.111642e+01     52.715305
# notnull   1.640000e+02    164.000000
# isnull    0.000000e+00      0.000000

# %% [markdown]
# - Most of the property has `BEDROOM_NUM` of **2, 3 and 4**.
# - Most of the property are **3BHK**.
# - Only **165** properties have more than **5BHK**.

# %% [markdown]
# ## BALCONY_NUM

# %%
df["BALCONY_NUM"].value_counts().sort_index().plot.bar()
# Out:
# <Axes: xlabel='BALCONY_NUM'>

# %%
lte_1_balcony = df.query("BALCONY_NUM<=1")
print(lte_1_balcony.shape)
summary.custom_describe(lte_1_balcony[["PRICE", "AREA"]])
# Out:
# (468, 33)
#                  PRICE           AREA
# count     4.680000e+02     468.000000
# mean      7.350363e+06    2481.797009
# std       1.341063e+07   24168.013284
# min       7.000000e+03     126.000000
# 1%        8.500000e+03     324.120000
# 5%        1.467500e+04     469.550000
# 25%       3.000000e+04     650.000000
# 50%       8.000000e+04    1074.000000
# 75%       8.025000e+06    1861.750000
# 95%       3.412500e+07    2985.000000
# 99%       7.029700e+07    4518.000000
# max       9.900000e+07  523812.000000
# skew      2.942181e+00      21.585137
# kurtosis  1.093088e+01     466.605089
# notnull   4.680000e+02     468.000000
# isnull    0.000000e+00       0.000000

# %% [markdown]
# ## FLOOR_NUM

# %% [markdown]
# ## BHK_BED

# %%
df["BHK_BED"].value_counts().sort_index().plot.bar()
# Out:
# <Axes: xlabel='BHK_BED'>

# %%
summary.compare_describe(df["BEDROOM_NUM"], df["BHK_BED"])
# Out:
#           BEDROOM_NUM as data1  BHK_BED as data2  data1 - data2  data1 ÷ data2
# count              9034.000000       9034.000000            0.0            1.0
# mean                  3.300199          3.300199            0.0            1.0
# std                   1.514894          1.514894            0.0            1.0
# min                   1.000000          1.000000            0.0            1.0
# 1%                    1.000000          1.000000            0.0            1.0
# 5%                    2.000000          2.000000            0.0            1.0
# 25%                   3.000000          3.000000            0.0            1.0
# 50%                   3.000000          3.000000            0.0            1.0
# 75%                   4.000000          4.000000            0.0            1.0
# 95%                   4.000000          4.000000            0.0            1.0
# 99%                   8.000000          8.000000            0.0            1.0
# max                  55.000000         55.000000            0.0            1.0
# skew                 12.686550         12.686550            0.0            1.0
# kurtosis            296.070003        296.070003            0.0            1.0
# notnull            9034.000000       9034.000000            0.0            1.0
# isnull              998.000000        998.000000            0.0            1.0

# %% [markdown]
# Hence, both `BALCONY_NUM` and `BHK_BED` columns are same. So, I need to drop `BHK_BED` column.

# %% [markdown]
# ## LOCALITY_NAME

# %%
df["LOCALITY_NAME"].nunique()
# Out:
# 265

# %%
df["LOCALITY_NAME"].value_counts()[:15]
# Out:
# LOCALITY_NAME
# sector 102 gurgaon    374
# dlf phase 2           266
# sector 65 gurgaon     258
# sector 57 gurgaon     235
# sector 48 gurgaon     231
# dlf phase 1           222
# sector 62 gurgaon     213
# sector 54 gurgaon     210
# sector 83 gurgaon     196
# sector 67a gurgaon    196
# sector 67 gurgaon     191
# sector 85 gurgaon     176
# sector 108 gurgaon    175
# sector 66 gurgaon     174
# dlf phase 5           165
# Name: count, dtype: int64

# %% [markdown]
# ## BUILDING_NAME

# %%
df["BUILDING_NAME"].sample(10, random_state=2)
# Out:
# 8411                              paras dews
# 3695                      vipul tatvam villa
# 1818    shapoorji pallonji joyville gurugram
# 9713                  emaar the palm springs
# 4234                  pioneer urban presidia
# 254                        top rated builder
# 6713                                     NaN
# 8719                        puri emerald bay
# 9566                   vatika sovereign next
# 3411                            dlf the icon
# Name: BUILDING_NAME, dtype: object

# %% [markdown]
# ## SOCIETY_NAME

# %%
df["SOCIETY_NAME"].sample(10, random_state=2)
# Out:
# 8411                              paras dews
# 3695                      vipul tatvam villa
# 1818    shapoorji pallonji joyville gurugram
# 9713                  emaar the palm springs
# 4234                  pioneer urban presidia
# 254                        top rated builder
# 6713                                     NaN
# 8719                        puri emerald bay
# 9566                   vatika sovereign next
# 3411                            dlf the icon
# Name: SOCIETY_NAME, dtype: object

# %% [markdown]
# ## BUILDING_NAME, SOCIETY_NAME

# %%
df[["BUILDING_NAME", "SOCIETY_NAME"]].sample(10)
# Out:
#                       BUILDING_NAME                   SOCIETY_NAME
# 3809                  pyramid urban                  pyramid urban
# 5135         dlf city plots phase 2         dlf city plots phase 2
# 148        signature global city 81       signature global city 81
# 1768      vatika independent floors      vatika independent floors
# 4330                     tulip leaf                     tulip leaf
# 9320         vatika lifestyle homes         vatika lifestyle homes
# 6871             dlf carlton estate             dlf carlton estate
# 757   brand nnew builder dlf city 2  brand nnew builder dlf city 2
# 242                             NaN                            NaN
# 3792                            NaN                            NaN

# %%
df["SOCIETY_NAME"].ne(df["BUILDING_NAME"]).sum()
# Out:
# 1804

# %% [markdown]
# ## ADDRESS

# %%
df["ADDRESS"].sample(10)
# Out:
# 8767                        NaN
# 6409                        NaN
# 6168                        NaN
# 3783                        NaN
# 314                        0000
# 3478                        NaN
# 7293    near huda meteo station
# 4052                        NaN
# 1271                      51-03
# 143                         NaN
# Name: ADDRESS, dtype: object

# %% [markdown]
# ## LANDMARKS
#
# #### TRANSPORATION, ACCOMODATION, LEISURE, EDUCATION, HEALTH, OTHER

# %%
landmarks = ["TRANSPORATION", "ACCOMODATION", "LEISURE", "EDUCATION", "HEALTH", "OTHER"]
df[["TOTAL_LANDMARK_COUNT", *landmarks]].sample(10)
# Out:
#       TOTAL_LANDMARK_COUNT  TRANSPORATION  ACCOMODATION  LEISURE  EDUCATION  \
# 7847                  47.0            0.0          10.0      2.0        0.0
# 9969                  15.0            3.0           0.0      0.0        0.0
# 9472                  13.0            2.0           3.0      4.0        2.0
# 7455                   NaN            0.0           0.0      0.0        0.0
# 5643                  45.0            0.0           4.0      2.0        0.0
# 4928                   6.0            1.0           1.0      1.0        0.0
# 1116                  13.0            2.0           2.0      2.0        2.0
# 9749                  44.0            0.0           3.0      1.0        0.0
# 3279                  45.0            6.0           8.0      0.0        0.0
# 5006                  47.0            1.0          11.0      0.0        2.0
#
#       HEALTH  OTHER
# 7847    17.0    2.0
# 9969     0.0   12.0
# 9472     1.0    1.0
# 7455     0.0    0.0
# 5643    21.0    2.0
# 4928     1.0    2.0
# 1116     1.0    4.0
# 9749    21.0    2.0
# 3279    19.0    1.0
# 5006    14.0    3.0

# %%
for col in landmarks:
    plt.figure()
    sns.histplot(df[col])

# %% [markdown]
# ### KMeans on LANDMARKS

# %%
landmarks_df = df[landmarks]

# %%
scaler = StandardScaler()
landmarks_scaled = scaler.fit_transform(landmarks_df)

# %%
cluster_range = range(1, 11)
wcss_reduced = []

for i in cluster_range:
    kmeans = KMeans(n_clusters=i, init="k-means++", n_init=10, random_state=42)
    kmeans.fit(landmarks_scaled)
    wcss_reduced.append(kmeans.inertia_)

# %%
# Plot the results
plt.figure(figsize=(15, 5))
plt.plot(cluster_range, wcss_reduced, marker="o", linestyle="--")

plt.title("Elbow Method for Optimal Number of Clusters (Reduced Range)")
plt.xlabel("Number of Clusters")
plt.ylabel("WCSS")
plt.grid(True)
plt.show()

# %%
best_n_clusters = 3

# Fit the KMeans model
kmeans = KMeans(n_clusters=best_n_clusters, init="k-means++", n_init=10, random_state=42)
kmeans.fit(landmarks_df)

# Predict the cluster assignments for each row
df["LANDMARKS_CLUSTER"] = kmeans.predict(landmarks_df)
df["LANDMARKS_CLUSTER"].value_counts()
# Out:
# LANDMARKS_CLUSTER
# 0    6959
# 2    1907
# 1    1166
# Name: count, dtype: int64

# %% [markdown]
# ## AMENITIES_SCORE, FEATURES_SCORE

# %%
scores = ["AMENITIES_SCORE", "FEATURES_SCORE"]
df[["TOTAL_LANDMARK_COUNT"] + landmarks + scores].sample(10)
# Out:
#       TOTAL_LANDMARK_COUNT  TRANSPORATION  ACCOMODATION  LEISURE  EDUCATION  \
# 7811                  45.0            0.0           3.0      2.0        0.0
# 4023                  15.0            2.0           2.0      3.0        2.0
# 5314                  15.0            3.0           3.0      4.0        2.0
# 2450                  46.0            0.0           4.0      1.0        0.0
# 2481                   4.0            0.0           3.0      0.0        0.0
# 2342                  47.0            3.0           3.0      0.0        2.0
# 220                   13.0            3.0           2.0      4.0        1.0
# 3962                  44.0            0.0           3.0      3.0        0.0
# 821                   44.0            6.0           7.0      0.0        0.0
# 5792                  46.0            2.0           6.0      0.0        2.0
#
#       HEALTH  OTHER  AMENITIES_SCORE  FEATURES_SCORE
# 7811    20.0    1.0               47              18
# 4023     1.0    5.0               98              53
# 5314     1.0    2.0               55              15
# 2450    21.0    2.0               53              18
# 2481     0.0    0.0               18               0
# 2342    13.0    2.0               82              36
# 220      2.0    1.0                0               0
# 3962    17.0    2.0               55              35
# 821     19.0    1.0                6               0
# 5792    11.0    3.0              124              61

# %%
for col in scores:
    plt.figure()
    sns.histplot(df[col])

# %% [markdown]
# ### KMeans on LANDMARKS

# %%
temp_df = df[landmarks + scores]
temp_df.isnull().sum()
# Out:
# TRANSPORATION      0
# ACCOMODATION       0
# LEISURE            0
# EDUCATION          0
# HEALTH             0
# OTHER              0
# AMENITIES_SCORE    0
# FEATURES_SCORE     0
# dtype: int64

# %%
scaler = StandardScaler()
temp_scaled = scaler.fit_transform(temp_df)

# %%
cluster_range = range(1, 11)
wcss_reduced = []

for i in cluster_range:
    kmeans = KMeans(n_clusters=i, init="k-means++", n_init=10, random_state=42)
    kmeans.fit(temp_scaled)
    wcss_reduced.append(kmeans.inertia_)

# %%
# Plot the results
plt.figure(figsize=(15, 5))
plt.plot(cluster_range, wcss_reduced, marker="o", linestyle="--")

plt.title("Elbow Method for Optimal Number of Clusters (Reduced Range)")
plt.xlabel("Number of Clusters")
plt.ylabel("WCSS")
plt.grid(True)
plt.show()

# %%
best_n_clusters = 4

# Fit the KMeans model
kmeans = KMeans(n_clusters=best_n_clusters, init="k-means++", n_init=10, random_state=42)
kmeans.fit(temp_df)

# Predict the cluster assignments for each row
df["LANDMARKS_N_SCORES_CLUSTER"] = kmeans.predict(temp_df)
df["LANDMARKS_N_SCORES_CLUSTER"].value_counts()
# Out:
# LANDMARKS_N_SCORES_CLUSTER
# 2    2757
# 0    2665
# 3    2577
# 1    2033
# Name: count, dtype: int64

# %% [markdown]
# ## LANDMARKS_CLUSTER, LANDMARKS_W_SCORES_CLUSTER

# %%
clusters = ["LANDMARKS_CLUSTER", "LANDMARKS_N_SCORES_CLUSTER"]
df[clusters].value_counts()
# Out:
# LANDMARKS_CLUSTER  LANDMARKS_N_SCORES_CLUSTER
# 0                  0                             2265
#                    3                             2001
#                    2                             1576
#                    1                             1117
# 2                  2                              733
#                    1                              567
# 1                  2                              448
#                    1                              349
# 2                  3                              349
#                    0                              258
# 1                  3                              227
#                    0                              142
# Name: count, dtype: int64

# %% [markdown]
# ## General Steps - End

# %% [markdown]
# ### There is **no exporting** of `DataFrame`(s) in EDA notebooks.

# %%
df.columns
# Out:
# Index(['SPID', 'PROP_ID', 'CITY', 'PRICE', 'PRICE_SQFT', 'AREA',
#        'TOTAL_LANDMARK_COUNT', 'PROP_HEADING', 'DESCRIPTION', 'PROPERTY_TYPE',
#        'FURNISH', 'FACING', 'AGE', 'TOTAL_FLOOR', 'BEDROOM_NUM', 'PROP_NAME',
#        'BALCONY_NUM', 'FLOOR_NUM', 'LATITUDE', 'LONGITUDE', 'BHK_BED',
#        'LOCALITY_NAME', 'BUILDING_NAME', 'SOCIETY_NAME', 'ADDRESS',
#        'TRANSPORATION', 'ACCOMODATION', 'LEISURE', 'EDUCATION', 'HEALTH',
#        'OTHER', 'AMENITIES_SCORE', 'FEATURES_SCORE', 'LANDMARKS_CLUSTER',
#        'LANDMARKS_N_SCORES_CLUSTER'],
#       dtype='object')

# %%
drop_cols = [
    "SPID",
    "BHK_BED",
    "BUILDING_NAME",
    "SOCIETY_NAME",
    "ADDRESS",
    "TRANSPORATION",
    "ACCOMODATION",
    "LEISURE",
    "EDUCATION",
    "HEALTH",
    "OTHER",
    "AMENITIES_SCORE",
    "FEATURES_SCORE",
]
print(f"After analysis columns to drop: {drop_cols}")
# Out:
# After analysis columns to drop: ['SPID', 'BHK_BED', 'BUILDING_NAME', 'SOCIETY_NAME', 'ADDRESS', 'TRANSPORATION', 'ACCOMODATION', 'LEISURE', 'EDUCATION', 'HEALTH', 'OTHER', 'AMENITIES_SCORE', 'FEATURES_SCORE']

# %%
df.sample(8)
# Out:
#           SPID    PROP_ID     CITY       PRICE  PRICE_SQFT     AREA  \
# 2758  70191426  h70191426  gurgaon  30000000.0     13636.0   2200.0
# 1648  70722302  l70722302  gurgaon    250000.0        55.0   4500.0
# 8109  50446040  o50446040  gurgaon   3500000.0      2916.0   1200.0
# 278   69913556  p69913556  gurgaon     35000.0         1.0  34000.0
# 3812  70926226  r70926226  gurgaon   6500000.0      5416.0   1200.0
# 2550  70434558  a70434558  gurgaon     58000.0       184.0   2835.0
# 2428  70124728  z70124728  gurgaon     45000.0        18.0   2408.0
# 4271  70282608  b70282608  gurgaon  39000000.0     18813.0   2073.0
#
#       TOTAL_LANDMARK_COUNT                                     PROP_HEADING  \
# 2758                  45.0  4 bhk independent builder floor in south city 2
# 1648                  44.0   4 bhk independent builder floor in dlf phase 2
# 8109                  48.0  2 bhk independent builder floor in shanti nagar
# 278                   49.0            3 bedroom house in sector 10a gurgaon
# 3812                  11.0                 2 bhk flat in sector 67a gurgaon
# 2550                  44.0   3 bhk independent builder floor in dlf phase 2
# 2428                  13.0                  3 bhk flat in sector 85 gurgaon
# 4271                  12.0                 3 bhk flat in sector 108 gurgaon
#
#                                             DESCRIPTION  \
# 2758  location: gurgaon sec. 49 south city 2 near: p...
# 1648  brand new builderfloor in dlf phase 2 gurgaon ...
# 8109  why pay rent  get ready to move  2 bhk front s...
# 278   rent this 3 bhk house in gurgaon's most sought...
# 3812  new property prime location on road  near by a...
# 2550  carefully laid out in the prime location of gu...
# 2428  this is 3bhk semi furnished flat in sec 85 gur...
# 4271  this 3 bhk apartment is available for sale in ...
#
#                   PROPERTY_TYPE        FURNISH FACING                    AGE  \
# 2758  independent/builder floor  not available  North  0-1 Year Old Property
# 1648  independent/builder floor    Unfurnished  South  0-1 Year Old Property
# 8109  independent/builder floor      Furnished   East  0-1 Year Old Property
# 278     independent house/villa  Semifurnished   East  0-1 Year Old Property
# 3812      residential apartment      Furnished   East  1-5 Year Old Property
# 2550  independent/builder floor  Semifurnished   East  1-5 Year Old Property
# 2428      residential apartment  Semifurnished  North  1-5 Year Old Property
# 4271      residential apartment    Unfurnished  North     Under Construction
#
#      TOTAL_FLOOR  BEDROOM_NUM      PROP_NAME  BALCONY_NUM FLOOR_NUM  \
# 2758         <15          4.0            NaN          4.0       <15
# 1648         <15          4.0            NaN          2.0       <15
# 8109         <15          2.0            NaN          1.0       <15
# 278          <15          3.0            NaN          3.0       >30
# 3812         <15          2.0  pyramid urban          1.0       <15
# 2550         <15          3.0            NaN          2.0         g
# 2428       15-30          3.0    ss the leaf          3.0       <15
# 4271       15-30          3.0     sobha city          3.0       <15
#
#        LATITUDE  LONGITUDE  BHK_BED       LOCALITY_NAME  BUILDING_NAME  \
# 2758  28.418353  77.053084      4.0        south city 2            NaN
# 1648  28.488963  77.086665      4.0         dlf phase 2            NaN
# 8109  28.444527  77.022730      2.0        shanti nagar            NaN
# 278   28.445676  77.007452      3.0  sector 10a gurgaon            NaN
# 3812  28.378112  77.056045      2.0  sector 67a gurgaon  pyramid urban
# 2550  28.488963  77.086665      3.0         dlf phase 2            NaN
# 2428  28.409748  76.953903      3.0   sector 85 gurgaon    ss the leaf
# 4271  28.516331  76.995685      3.0  sector 108 gurgaon     sobha city
#
#        SOCIETY_NAME            ADDRESS  TRANSPORATION  ACCOMODATION  LEISURE  \
# 2758            NaN                001            0.0           4.0      3.0
# 1648            NaN                NaN            5.0           8.0      0.0
# 8109            NaN  tanishq residency            0.0           0.0      2.0
# 278             NaN                NaN            0.0           0.0      2.0
# 3812  pyramid urban                NaN            0.0           1.0      3.0
# 2550            NaN                NaN            5.0           8.0      0.0
# 2428    ss the leaf                NaN            1.0           2.0      3.0
# 4271     sobha city            tower z            3.0           2.0      3.0
#
#       EDUCATION  HEALTH  OTHER  AMENITIES_SCORE  FEATURES_SCORE  \
# 2758        0.0    18.0    2.0               57              20
# 1648        0.0    13.0    3.0               30               5
# 8109        0.0    41.0    3.0               39               8
# 278         0.0    42.0    4.0               35               7
# 3812        6.0     0.0    1.0               52              24
# 2550        0.0    13.0    3.0               53              18
# 2428        2.0     1.0    4.0              118              61
# 4271        2.0     1.0    1.0               97              43
#
#       LANDMARKS_CLUSTER  LANDMARKS_N_SCORES_CLUSTER
# 2758                  1                           2
# 1648                  2                           1
# 8109                  1                           2
# 278                   1                           1
# 3812                  0                           2
# 2550                  2                           2
# 2428                  0                           0
# 4271                  0                           3
